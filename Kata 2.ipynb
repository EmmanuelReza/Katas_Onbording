# %% [markdown]
# # Kata 2.- Crear y administrar proyectos
# # Creacion de un Entorno Virtual

# %%
import IPython.display as display
from PIL import Image
display.display(Image.open('C:\\Users\\emman\\OneDrive\\Escritorio\\LaunchX\\Onbording\\Katas Realizadas\\Kata 2\\SS1.jpg'))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x261 at 0x1CD66B5AFB0>

# %%
display.display(Image.open('C:\\Users\\emman\\OneDrive\\Escritorio\\LaunchX\\Onbording\\Katas Realizadas\\Kata 2\\SS2.jpg'))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=818x203 at 0x1CD66F39330>

# %%
display.display(Image.open('C:\\Users\\emman\\OneDrive\\Escritorio\\LaunchX\\Onbording\\Katas Realizadas\\Kata 2\\SS3.jpg'))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=961x183 at 0x1CD66C43E80>

# %%
display.display(Image.open('C:\\Users\\emman\\OneDrive\\Escritorio\\LaunchX\\Onbording\\Katas Realizadas\\Kata 2\\SS4.jpg'))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=978x216 at 0x1CD66F393C0>

# %%
display.display(Image.open('C:\\Users\\emman\\OneDrive\\Escritorio\\LaunchX\\Onbording\\Katas Realizadas\\Kata 2\\SS5.jpg'))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=983x263 at 0x1CD66F39B10>

# %%
display.display(Image.open('C:\\Users\\emman\\OneDrive\\Escritorio\\LaunchX\\Onbording\\Katas Realizadas\\Kata 2\\SS6.jpg'))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=985x279 at 0x1CD66F39E10>
